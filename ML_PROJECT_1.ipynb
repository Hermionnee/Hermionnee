# %% [markdown]
# <a href="https://colab.research.google.com/github/Hermionnee/Hermionnee/blob/main/ML_PROJECT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **ML**- FIRST PROJECT

# %% [markdown]
# # Load Data :

# %%
import pandas as pd
df = pd.read_csv("/content/airport-codes_csv.csv")
df
# Out:
#          ident            type                                name  \
# 0          00A        heliport                   Total Rf Heliport
# 1         00AA   small_airport                Aero B Ranch Airport
# 2         00AK   small_airport                        Lowell Field
# 3         00AL   small_airport                        Epps Airpark
# 4         00AR          closed  Newport Hospital & Clinic Heliport
# ...        ...             ...                                 ...
# 57416     ZYYK  medium_airport               Yingkou Lanqi Airport
# 57417     ZYYY  medium_airport             Shenyang Dongta Airport
# 57418  ZZ-0001        heliport                     Sealand Helipad
# 57419  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 57420     ZZZZ   small_airport             Satsuma IÅjima Airport
#
#        elevation_ft continent iso_country iso_region      municipality  \
# 0              11.0       NaN          US      US-PA          Bensalem
# ...

# %% [markdown]
# # **Data preparation :**

# %% [markdown]
# ## Data separation as x and y

# %%
y = df ['coordinates']
y
# Out:
# 0             -74.93360137939453, 40.07080078125
# 1                         -101.473911, 38.704022
# 2                    -151.695999146, 59.94919968
# 3          -86.77030181884766, 34.86479949951172
# 4                            -91.254898, 35.6087
#                           ...
# 57416                        122.3586, 40.542524
# 57417     123.49600219726562, 41.784400939941406
# 57418                          1.4825, 51.894444
# 57419    47.296388888900005, -11.584277777799999
# 57420                      130.270556, 30.784722
# Name: coordinates, Length: 57421, dtype: object

# %%
x = df.drop('coordinates', axis=1)
x
# Out:
#          ident            type                                name  \
# 0          00A        heliport                   Total Rf Heliport
# 1         00AA   small_airport                Aero B Ranch Airport
# 2         00AK   small_airport                        Lowell Field
# 3         00AL   small_airport                        Epps Airpark
# 4         00AR          closed  Newport Hospital & Clinic Heliport
# ...        ...             ...                                 ...
# 57416     ZYYK  medium_airport               Yingkou Lanqi Airport
# 57417     ZYYY  medium_airport             Shenyang Dongta Airport
# 57418  ZZ-0001        heliport                     Sealand Helipad
# 57419  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 57420     ZZZZ   small_airport             Satsuma IÅjima Airport
#
#        elevation_ft continent iso_country iso_region      municipality  \
# 0              11.0       NaN          US      US-PA          Bensalem
# ...

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

# %%
x_train # -> a subset to train a model.
        # -> We have considered x variables
        # -> In this block we recieve 80% of 57421 rows
        # -> Therefore, x_train will have 80% of the data
# Out:
#          ident           type                                name  \
# 42361  RU-3693  small_airport              Letneozerskiy Air Base
# 13384  BR-0906  small_airport          Fazenda Rio XingÃº Airport
# 26139  JP-0006         closed                      Kokura Airport
# 37536     NE02       heliport  Pender Community Hospital Heliport
# 4282      3GA9  small_airport                       Vintage Field
# ...        ...            ...                                 ...
# 12119     AZ60         closed                     Coyner Airstrip
# 57191  ZM-0007  small_airport                       Kafue Airport
# 14147  CA-0493  small_airport                        Foxden Farms
# 56088     YMNK  small_airport                     Monkira Airport
# 38408     NWWP  small_airport                        Poum Airport
#
#        elevation_ft continent iso_country iso_region         municipality  \
# 42361         325.0        EU          RU     RU-ARK           Obozerskiy
# ...

# %%
x_test  # -> a subset to test the trained model.
        # -> We have considered x variables
        # -> In this block we recieve 20% of 57421 rows
        # Therefore, x_test will have 20% of the data
# Out:
#          ident           type                                 name  \
# 45422     SJPI  small_airport          Fazenda Pirapitinga Airport
# 14586     CAX7  seaplane_base        Minstrel Island Seaplane Base
# 19174     EG19  small_airport              Boon Hill Farm Airstrip
# 40834     PS15  small_airport               Vicars Private Airport
# 23396  GB-0678  small_airport             Marsh Hill Farm Airstrip
# ...        ...            ...                                  ...
# 18215     DIDK  small_airport                     Dimbokro Airport
# 26285  JP-0152       heliport  Shintaiso Building Number 4 Helipad
# 9126      8GA7  small_airport               Etowah Bend Gliderport
# 11588  AU-0015  small_airport                   Bremer Bay Airport
# 30793  KR-0718       heliport       Digital Cube Building Heliport
#
#        elevation_ft continent iso_country iso_region            municipality  \
# 45422        2510.0        SA          BR      BR-GO    Cocalzinho De GoiÃ¡s
# ...

# %% [markdown]
# # **Model building :**

# %% [markdown]
# ### **Linear Regression**

# %% [markdown]
# **Training the model**

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-4ad3c3c8273a> in <cell line: 4>()
#       2
#       3 lr = LinearRegression()
# ----> 4 lr.fit(x_train, y_train)
#       5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     646         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     647
# --> 648         X, y = self._validate_data(
#     649             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
# ...

# %% [markdown]
# **Applying the model to make a prediction**

# %%
y_lr_train_pred =   lr.predict(x_train)
y_lr_test_pred =   lr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f103858eb06a> in <cell line: 1>()
# ----> 1 y_lr_train_pred =   lr.predict(x_train)
#       2 y_lr_test_pred =   lr.predict(x_test)
#
# NameError: name 'lr' is not defined
